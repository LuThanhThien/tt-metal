# %% [markdown]
# # Multi-Head Attention
#
# Multi-Head Attention is an important part of all Transformer-based models.
# This tutorial will show how to write it and how to then optimize it.

# %% [markdown]
# If you're using a Wormhole card (N150/N300), you will need to set the full Tensix available to be able to continue with this tutorial

# %%
import os
os.environ["WH_ARCH_YAML"] = "wormhole_b0_80_arch_eth_dispatch.yaml"

# %%
import time
import torch
import ttnn

torch.manual_seed(0)

device_id = 0
device = ttnn.open_device(device_id=device_id, l1_small_size=8192)
# Out:
# 2024-08-21 05:38:58.907 | DEBUG    | ttnn:<module>:82 - Initial ttnn.CONFIG:
# Config{cache_path=/home/thienluu/.cache/ttnn,model_cache_path=/home/thienluu/.cache/ttnn/models,tmp_dir=/tmp/ttnn,enable_model_cache=false,enable_fast_runtime_mode=true,throw_exception_on_fallback=false,enable_logging=false,enable_graph_report=false,enable_detailed_buffer_report=false,enable_detailed_tensor_report=false,enable_comparison_mode=false,comparison_mode_pcc=0.9999,root_report_path=generated/ttnn/reports,report_name=std::nullopt,std::nullopt}
# 2024-08-21 05:38:58.971 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.pearson_correlation_coefficient be migrated to C++?
# 2024-08-21 05:38:58.973 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.Conv1d be migrated to C++?
# 2024-08-21 05:38:58.977 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.conv2d be migrated to C++?
# 2024-08-21 05:38:58.978 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.reshape be migrated to C++?
# 2024-08-21 05:38:58.979 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.unsqueeze_to_4D be migrated to C++?
# 2024-08-21 05:38:58.979 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.squeeze be migrated to C++?
# 2024-08-21 05:38:58.980 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.from_torch be migrated to C++?
# 2024-08-21 05:38:58.980 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.to_torch be migrated to C++?
# 2024-08-21 05:38:58.981 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.to_device be migrated to C++?
# 2024-08-21 05:38:58.981 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.from_device be migrated to C++?
# 2024-08-21 05:38:58.982 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.allocate_tensor_on_device be migrated to C++?
# 2024-08-21 05:38:58.982 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.copy_host_to_device_tensor be migrated to C++?
# 2024-08-21 05:38:58.983 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.deallocate be migrated to C++?
# 2024-08-21 05:38:58.983 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.clone be migrated to C++?
# 2024-08-21 05:38:58.984 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.reallocate be migrated to C++?
# 2024-08-21 05:38:58.984 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.load_tensor be migrated to C++?
# 2024-08-21 05:38:58.985 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.dump_tensor be migrated to C++?
# 2024-08-21 05:38:58.985 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.as_tensor be migrated to C++?
# 2024-08-21 05:38:58.989 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.matmul be migrated to C++?
# 2024-08-21 05:38:58.989 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.linear be migrated to C++?
# 2024-08-21 05:38:58.991 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.max_pool2d be migrated to C++?
# 2024-08-21 05:38:58.991 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.max_pool2d_legacy be migrated to C++?
# 2024-08-21 05:38:58.992 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.global_avg_pool2d be migrated to C++?
# 2024-08-21 05:38:58.992 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.avg_pool2d be migrated to C++?
# 2024-08-21 05:38:58.995 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.matmul be migrated to C++?
# 2024-08-21 05:38:58.996 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.linear be migrated to C++?
# 2024-08-21 05:38:58.997 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.conv2d be migrated to C++?
# 2024-08-21 05:38:58.998 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.max_pool2d be migrated to C++?
# 2024-08-21 05:38:58.999 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.max_pool2d_legacy be migrated to C++?
# 2024-08-21 05:38:58.999 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.global_avg_pool2d be migrated to C++?
# 2024-08-21 05:38:59.000 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.avg_pool2d be migrated to C++?
# 2024-08-21 05:38:59.001 | WARNING  | ttnn.decorators:operation_decorator:790 - Should ttnn.Conv1d be migrated to C++?
#                  Device | INFO     | Opening user mode device driver
# 2024-08-21 05:38:59.032 | INFO     | SiliconDriver   - Detected 8 PCI devices : [0, 1, 2, 3, 4, 5, 6, 7]
# 2024-08-21 05:38:59.109 | INFO     | SiliconDriver   - Detected 8 PCI devices : [0, 1, 2, 3, 4, 5, 6, 7]
# 2024-08-21 05:38:59.121 | INFO     | SiliconDriver   - Detected 8 PCI devices : [0, 1, 2, 3, 4, 5, 6, 7]
# 2024-08-21 05:38:59.133 | INFO     | SiliconDriver   - Detected 8 PCI devices : [0, 1, 2, 3, 4, 5, 6, 7]
# 2024-08-21 05:38:59.151 | INFO     | SiliconDriver   - Detected 8 PCI devices : [0, 1, 2, 3, 4, 5, 6, 7]
# 2024-08-21 05:38:59.169 | INFO     | SiliconDriver   - Detected 8 PCI devices : [0, 1, 2, 3, 4, 5, 6, 7]
# 2024-08-21 05:38:59.186 | INFO     | SiliconDriver   - Detected 8 PCI devices : [0, 1, 2, 3, 4, 5, 6, 7]
# 2024-08-21 05:38:59.207 | INFO     | SiliconDriver   - Detected 8 PCI devices : [0, 1, 2, 3, 4, 5, 6, 7]
#                   Metal | INFO     | Initializing device 0. Program cache is NOT enabled
#                   Metal | INFO     | Running with 1 cqs
#                   Metal | INFO     | AI CLK for device 0 is:   1300 MHz
#                   Metal | INFO     | DPRINT enabled on device 0, all worker cores.
#                   Metal | INFO     | DPRINT Server attached device 0
# prefetcher_11: start
# dispatch_11: start

# %% [markdown]
# ## Enable program cache

# %%
ttnn.enable_program_cache(device)
# Out:
#                   Metal | INFO     | Enabling program cache on device 0

# %% [markdown]
# ## Write Multi-Head Attention using ttnn
#
# Multi-head can be implemented in `torch` using just 6 operations:
#
# 1. `torch.matmul`
# 2. `torch.add`
# 3. `torch.reshape`
# 4. `torch.permute`
# 5. `torch.mul`
# 6. `torch.softmax`
#
# `ttnn` provides the exact same APIs to do that and therefore multi-head attention can be implemented in a very similar fashion. Except, when using `ttnn`, the user should be mindful of the tensor layout.

# %%
@ttnn.log_runtime
def multi_head_attention(
    hidden_states,
    attention_mask,
    query_weight,
    query_bias,
    key_weight,
    key_bias,
    value_weight,
    value_bias,
    output_weight,
    output_bias,
    *,
    num_heads,
):
    fallback_reshape = ttnn.get_fallback_function(ttnn.reshape) 
       
    batch_size, sequence_size, hidden_size = hidden_states.shape
    head_size = hidden_size // num_heads

    query = hidden_states @ query_weight
    query = query + query_bias
    query = ttnn.to_layout(query, layout=ttnn.ROW_MAJOR_LAYOUT)
    query = fallback_reshape(query, (batch_size, sequence_size, num_heads, head_size))
    query = ttnn.to_layout(query, layout=ttnn.TILE_LAYOUT)
    query = ttnn.permute(query, (0, 2, 1, 3))

    key = hidden_states @ key_weight
    key = key + key_bias
    key = ttnn.to_layout(key, layout=ttnn.ROW_MAJOR_LAYOUT)
    key = fallback_reshape(key, (batch_size, sequence_size, num_heads, head_size))
    key = ttnn.to_layout(key, layout=ttnn.TILE_LAYOUT)
    key = ttnn.permute(key, (0, 2, 3, 1))

    value = hidden_states @ value_weight
    value = value + value_bias
    value = ttnn.to_layout(value, layout=ttnn.ROW_MAJOR_LAYOUT)
    value = fallback_reshape(value, (batch_size, sequence_size, num_heads, head_size))
    value = ttnn.to_layout(value, layout=ttnn.TILE_LAYOUT)
    value = ttnn.permute(value, (0, 2, 1, 3))

    attention_scores = query @ key
    attention_scores = attention_scores * (1 / (head_size**0.5))
    attention_scores += attention_mask
    attention_probs = ttnn.softmax(attention_scores, dim=-1)

    context_layer = attention_probs @ value
    context_layer = ttnn.permute(context_layer, (0, 2, 1, 3))
    context_layer = ttnn.to_layout(context_layer, layout=ttnn.ROW_MAJOR_LAYOUT)
    context_layer = fallback_reshape(context_layer, (batch_size, sequence_size, hidden_size))
    context_layer = ttnn.to_layout(context_layer, layout=ttnn.TILE_LAYOUT)

    self_output = context_layer @ output_weight
    self_output = self_output + output_bias

    return self_output

# %% [markdown]
# Now that the model is written, let's create input tensors to run it and test it

# %% [markdown]
# ## Configuration

# %%
batch_size = 8
sequence_size = 384
num_heads = 16
head_size = 64
hidden_size = num_heads * head_size

# %% [markdown]
# ## Initialize activations and weights using torch

# %%
torch_hidden_states = torch.randn((batch_size, sequence_size, hidden_size), dtype=torch.bfloat16)
torch_attention_mask = torch.randn((batch_size, 1, 1, sequence_size), dtype=torch.bfloat16)
torch_query_weight = torch.randn((hidden_size, hidden_size), dtype=torch.bfloat16)
torch_query_bias = torch.randn((hidden_size,), dtype=torch.bfloat16)
torch_key_weight = torch.randn((hidden_size, hidden_size), dtype=torch.bfloat16)
torch_key_bias = torch.randn((hidden_size,), dtype=torch.bfloat16)
torch_value_weight = torch.randn((hidden_size, hidden_size), dtype=torch.bfloat16)
torch_value_bias = torch.randn((hidden_size,), dtype=torch.bfloat16)
torch_output_weight = torch.randn((hidden_size, hidden_size), dtype=torch.bfloat16)
torch_output_bias = torch.randn((hidden_size,), dtype=torch.bfloat16)

# %% [markdown]
# ## Convert activations and weights to ttnn

# %%
hidden_states = ttnn.from_torch(torch_hidden_states, layout=ttnn.TILE_LAYOUT, device=device)
attention_mask = ttnn.from_torch(torch_attention_mask, layout=ttnn.TILE_LAYOUT, device=device)
query_weight = ttnn.from_torch(torch_query_weight, layout=ttnn.TILE_LAYOUT, device=device)
query_bias = ttnn.from_torch(torch_query_bias, layout=ttnn.TILE_LAYOUT, device=device, memory_config=ttnn.L1_MEMORY_CONFIG)
key_weight = ttnn.from_torch(torch_key_weight, layout=ttnn.TILE_LAYOUT, device=device)
key_bias = ttnn.from_torch(torch_key_bias, layout=ttnn.TILE_LAYOUT, device=device, memory_config=ttnn.L1_MEMORY_CONFIG)
value_weight = ttnn.from_torch(torch_value_weight, layout=ttnn.TILE_LAYOUT, device=device)
value_bias = ttnn.from_torch(torch_value_bias, layout=ttnn.TILE_LAYOUT, device=device, memory_config=ttnn.L1_MEMORY_CONFIG)
output_weight = ttnn.from_torch(torch_output_weight, layout=ttnn.TILE_LAYOUT, device=device)
output_bias = ttnn.from_torch(torch_output_bias, layout=ttnn.TILE_LAYOUT, device=device, memory_config=ttnn.L1_MEMORY_CONFIG)
# Out:
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 33 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 16 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 0
# process_write_paged - pages: 32 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 16 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 0
# process_write_paged - pages: 32 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 16 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 0
# process_write_paged - pages: 32 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 16 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 0
# process_write_paged - pages: 32 page_size: 2048 dispatch_cb_page_size: 4096

# %% [markdown]
# ## Run the first iteration of Multi-Head Attention

# %%
start = time.time()
multi_head_attention(
    hidden_states,
    attention_mask,
    query_weight,
    query_bias,
    key_weight,
    key_bias,
    value_weight,
    value_bias,
    output_weight,
    output_bias,
    num_heads=num_heads,
)
end = time.time()
duration = end - start
# Out:
# Function 'ttnn.matmul' executed in 0.4110 seconds
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 14 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102240 0
# cmd_write_packed
# dispatch_write_packed: 72 80 397456 31 102240
# cmd_write_packed
# dispatch_write_packed: 92 96 401440 1 102240
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 0
# cmd_write_packed
# dispatch_write_packed: 4 16 409632 2 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 413728 2 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 417824 2 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 475184 4 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 32
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 8 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102336 0
# cmd_write_packed
# dispatch_write_packed: 108 112 508352 108 102336
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 32
# cmd_write_packed
# dispatch_write_packed: 272 272 528416 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 544800 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 140
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 7 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102448 0
# cmd_write_packed
# dispatch_write_packed: 48 48 573840 96 102448
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 140
# cmd_write_packed
# dispatch_write_packed: 272 272 585760 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 602144 1 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 236
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 236
# cmd_write_packed
# dispatch_write_packed: 16 16 618528 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 236
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# proceFunction 'ttnn.matmul' executed in 0.0001 seconds
# ss_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 128 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 236
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 12 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102496 0
# cmd_write_packed
# dispatch_write_packed: 52 64 151584 1 102496
# cmd_write_packed
# dispatch_write_packed: 68 80 156096 105 102496
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 236
# cmd_write_packed
# dispatch_write_packed: 272 272 172064 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 204848 3 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 342
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 12 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102576 0
# cmd_write_packed
# dispatch_write_packed: 48 48 245792 1 102576
# cmd_write_packed
# dispatch_write_packed: 64 64 250304 105 102576
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 342
# cmd_write_packed
# dispatch_write_packed: 272 272 262176 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 294960 3 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 448
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 9 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102640 0
# cmd_write_packed
# dispatch_write_packed: 80 80 327712 1 102640
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 448
# cmd_write_packed
# dispatch_write_packed: 272 272 335904 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 352288 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 449
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 4 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102720 0
# cmd_write_packed
# dispatch_write_packed: 68 80 377280 108 102720
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 449
# cmd_write_packed
# dispatch_write_packed: 16 16 393248 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 405536 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 557
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 4 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102800 0
# cmd_write_packed
# dispatch_write_packed: 36 48 430528 108 102800
# cmd_write_packed
# dispatch_write_packed: 36 0 438304 1 102848
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 557
# cmd_write_packed
# dispatch_write_packed: 16 16 446496 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 458784 1 32
# write offset: 0 102896 0
# cmd_write_packed
# dispatch_write_packed: 72 80 467088 31 102896
# cmd_write_packed
# dispatch_write_packed: 92 96 471072 1 102896
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 665
# cmd_write_packed
# dispatch_write_packed: 4 16 479264 2 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 483360 2 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 487456 2 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 544816 4 32
# write offset: 0 102992 0
# cmd_write_packed
# dispatch_write_packed: 108 112 553408 108 102992
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 697
# cmd_write_packed
# dispatch_write_packed: 272 272 573472 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 589856 1 32
# write offset: 0 103104 0
# cmd_write_packed
# dispatch_write_packed: 48 48 598416 96 103104
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 805
# cmd_write_packed
# dispatch_write_packed: 272 272 610336 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 626720 1 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 901
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 901
# cmd_write_packed
# dispatch_write_packed: 16 16 118816 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 901
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# Function 'ttnn.matmul' executed in 0.0001 seconds
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 128 dispatch_cb_page_size: 4096
# write offset: 0 103152 0
# cmd_write_packed
# dispatch_write_packed: 52 64 143392 1 103152
# cmd_write_packed
# dispatch_write_packed: 68 80 147904 105 103152
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 901
# cmd_write_packed
# dispatch_write_packed: 272 272 163872 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 196656 3 32
# write offset: 0 103232 0
# cmd_write_packed
# dispatch_write_packed: 48 48 204832 1 103232
# cmd_write_packed
# dispatch_write_packed: 64 64 209344 105 103232
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1007
# cmd_write_packed
# dispatch_wriFunction 'ttnn.matmul' executed in 0.3995 seconds
# te_packed: 272 272 221216 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 254000 3 32
# write offset: 0 103296 0
# cmd_write_packed
# dispatch_write_packed: 80 80 262176 1 103296
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1113
# cmd_write_packed
# dispatch_write_packed: 272 272 270368 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 286752 1 32
# write offset: 0 103376 0
# cmd_write_packed
# dispatch_write_packed: 68 80 295360 108 103376
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1114
# cmd_write_packed
# dispatch_write_packed: 16 16 311328 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 323616 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1222
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 8 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 103456 0
# cmd_write_packed
# dispatch_write_packed: 48 48 356800 108 103456
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 1222
# cmd_write_packed
# dispatch_write_packed: 272 272 368672 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 385056 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1330
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 4 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 103504 0
# cmd_write_packed
# dispatch_write_packed: 36 48 410048 108 103504
# cmd_write_packed
# dispatch_write_packed: 36 0 417824 1 103552
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 1330
# cmd_write_packed
# dispatch_write_packed: 16 16 426016 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 438304 1 32
# write offset: 0 103600 0
# cmd_write_packed
# dispatch_write_packed: 72 80 446608 31 103600
# cmd_write_packed
# dispatch_write_packed: 92 96 450592 1 103600
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1438
# cmd_write_packed
# dispatch_write_packed: 4 16 458784 2 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 462880 2 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 466976 2 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 524336 4 32
# write offset: 0 103696 0
# cmd_write_packed
# dispatch_write_packed: 108 112 532928 108 103696
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1470
# cmd_write_packed
# dispatch_write_packed: 272 272 552992 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 569376 1 32
# write offset: 0 103808 0
# cmd_write_packed
# dispatch_write_packed: 48 48 577936 96 103808
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1578
# cmd_write_packed
# dispatch_write_packed: 272 272 589856 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 606240 1 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 1674
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1674
# cmd_write_packed
# dispatch_write_packed: 16 16 622624 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1674
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# Function 'ttnn.matmul' executed in 0.3881 seconds
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 128 dispatch_cb_page_size: 4096
# write offset: 0 103856 0
# cmd_write_packed
# dispatch_write_packed: 52 64 122912 1 103856
# cmd_write_packed
# dispatch_write_packed: 68 80 127424 105 103856
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1674
# cmd_write_packed
# dispatch_write_packed: 272 272 143392 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 176176 3 32
# write offset: 0 103936 0
# cmd_write_packed
# dispatch_write_packed: 48 48 184352 1 103936
# cmd_write_packed
# dispatch_write_packed: 64 64 188864 105 103936
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1780
# cmd_write_packed
# dispatch_write_packed: 272 272 200736 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 233520 3 32
# write offset: 0 104000 0
# cmd_write_packed
# dispatch_write_packed: 80 80 241696 1 104000
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1886
# cmd_write_packed
# dispatch_write_packed: 272 272 249888 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 266272 1 32
# write offset: 0 104080 0
# cmd_write_packed
# dispatch_write_packed: 68 80 274880 108 104080
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1887
# cmd_write_packed
# dispatch_write_packed: 16 16 290848 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 303136 1 32
# write offset: 0 104160 0
# cmd_write_packed
# dispatch_write_packed: 36 48 311744 108 104160
# cmd_write_packed
# dispatch_write_packed: 36 0 319520 1 104208
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 1995
# cmd_write_packed
# dispatch_write_packed: 16 16 327712 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 340000 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2103
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 12 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 104256 0
# cmd_write_packed
# dispatch_write_packed: 60 64 381088 36 104256
# cmd_write_packed
# dispatch_write_packed: 60 64 385328 72 104256
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2103
# cmd_write_packed
# dispatch_write_packed: 272 272 397344 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 421920 2 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2211
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2211
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 8 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 104320 0
# cmd_write_packed
# dispatch_write_packed: 52 64 463296 108 104320
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2211
# cmd_write_packed
# dispatch_write_packed: 272 272 475168 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 491552 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2319
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 8 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 104384 0
# cmd_write_packed
# dispatch_write_packed: 108 112 524736 108 104384
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2319
# cmd_write_packed
# dispatch_write_packed: 272 272 544800 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 561184 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2427
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 14 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 104496 0
# cmd_write_packed
# dispatch_write_packed: 96 96 606656 108 104496
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2427
# cmd_write_packed
# dispatch_write_packed: 416 416 622624 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 122912 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2535
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 12 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 104592 0
# cmd_write_packed
# dispatch_write_packed: 60 64 164096 60 104592
# cmd_write_packed
# dispatch_write_packed: 60 64 168144 48 104592
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2535
# cmd_write_packed
# dispatch_write_packed: 272 272 176160 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 217136 4 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2643
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 4 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 104656 0
# cmd_write_packed
# dispatch_write_packed: 52 64 241696 1 104656
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2643
# cmd_write_packed
# dispatch_write_packed: 32 32 249888 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 262176 1 32
# write offset: 0 104720 0
# cmd_write_packed
# dispatch_write_packed: 68 80 270784 108 104720
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2644
# cmd_write_packed
# dispatch_write_packed: 16 16 286752 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 299040 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2752
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 9 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 104800 0
# cmd_write_packed
# dispatch_write_packed: 76 80 331808 1 104800
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2752
# cmd_write_packed
# dispatch_write_packed: 272 272 340000 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 356384 1 32
# write offset: 0 104880 0
# cmd_write_packed
# dispatch_write_packed: 52 64 364576 1 104880
# cmd_write_packed
# dispatch_write_packed: 68 80 369088 105 104880
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2753
# cmd_write_packed
# dispatch_write_packed: 272 272 385056 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 417840 3 32
# write offset: 0 104960 0
# cmd_write_packed
# dispatch_write_packed: 48 48 426016 1 104960
# cmd_write_packed
# dispatch_write_packed: 64 64 430528 105 104960
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2859
# cmd_write_packed
# dispatch_write_packed: 272 272 442400 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 475184 3 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2965
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2965
# cmd_write_packed
# dispatch_write_packed: 16 16 491552 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# Function 'ttnn.matmul' executed in 0.0002 secondscmd_wait
#  DISPATCH WAIT 1a3b0 count 2965
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages:
# Function 'multi_head_attention' executed in 31.6549 seconds
# 48 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 2965
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 8 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 105024 0
# cmd_write_packed
# dispatch_write_packed: 48 48 110992 96 105024
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 2965
# cmd_write_packed
# dispatch_write_packed: 272 272 122912 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 139296 1 32
# write offset: 0 105072 0
# cmd_write_packed
# dispatch_write_packed: 72 80 147600 31 105072
# cmd_write_packed
# dispatch_write_packed: 92 96 151584 1 105072
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 3061
# cmd_write_packed
# dispatch_write_packed: 4 16 159776 2 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 163872 2 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 167968 2 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 225328 4 32
# write offset: 0 105168 0
# cmd_write_packed
# dispatch_write_packed: 108 112 233920 108 105168
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 3093
# cmd_write_packed
# dispatch_write_packed: 272 272 253984 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 270368 1 32

# %%
print(f"Multi-head attention ran in {duration} seconds for the first iteration")
# Out:
# Multi-head attention ran in 31.655242681503296 seconds for the first iteration

# %% [markdown]
# ## Run a subsequent iteration of Multi-Head Attention

# %%
start = time.time()
output = multi_head_attention(
    hidden_states,
    attention_mask,
    query_weight,
    query_bias,
    key_weight,
    key_bias,
    value_weight,
    value_bias,
    output_weight,
    output_bias,
    num_heads=num_heads,
)
end = time.time()
duration = end - start
# Out:
# Function 'ttnn.matmul' executed in 0.0002 seconds
# write offset: 0 104016 0
# cmd_write_packed
# dispatch_write_packed: 72 80 258192 31 104016
# cmd_write_packed
# dispatch_write_packed: 92 96 262176 1 104016
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6402
# cmd_write_packed
# dispatch_write_packed: 4 16 270368 2 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 274464 2 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 278560 2 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 335920 4 32
# write offset: 0 104112 0
# cmd_write_packed
# dispatch_write_packed: 108 112 344512 108 104112
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6434
# cmd_write_packed
# dispatch_write_packed: 272 272 364576 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 380960 1 32
# write offset: 0 104224 0
# cmd_write_packed
# dispatch_write_packed: 48 48 389520 96 104224
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6542
# cmd_write_packed
# dispatch_write_packed: 272 272 401440 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 417824 1 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 6638
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6638
# cmd_write_packed
# dispatch_write_packed: 16 16 434208 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# Function 'ttnn.matmul' executed in 0.0001 seconds
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6638
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 128 dispatch_cb_page_size: 4096
# write offset: 0 104272 0
# cmd_write_packed
# dispatch_write_packed: 52 64 458784 1 104272
# cmd_write_packed
# dispatch_write_packed: 68 80 463296 105 104272
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6638
# cmd_write_packed
# dispatch_write_packed: 272 272 479264 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 512048 3 32
# write offset: 0 104352 0
# cmd_write_packed
# dispatch_write_packed: 48 48 520224 1 104352
# cmd_write_packed
# dispatch_write_packed: 64 64 524736 105 104352
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6744
# cmd_write_packed
# dispatch_write_packed: 272 272 536608 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 569392 3 32
# write offset: 0 104416 0
# cmd_write_packed
# dispatch_write_packed: 80 80 577568 1 104416
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6850
# cmd_write_packed
# dispatch_write_packed: 272 272 585760 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 602144 1 32
# write offset: 0 104496 0
# cmd_write_packed
# dispatch_write_packed: 68 80 610752 108 104496
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6851
# cmd_write_packed
# dispatch_write_packed: 16 16 626720 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 114720 1 32
# write offset: 0 104576 0
# cmd_write_packed
# dispatch_write_packed: 36 48 123328 108 104576
# cmd_write_packed
# dispatch_write_packed: 36 0 131104 1 104624
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 6959
# cmd_write_packed
# dispatch_write_packed: 16 16 139296 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 151584 1 32
# write offset: 0 104672 0
# cmd_write_packed
# dispatch_write_packed: 72 80 159888 31 104672
# cmd_write_packed
# dispatch_write_packed: 92 96 163872 1 104672
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7067
# cmd_write_packed
# dispatch_write_packed: 4 16 172064 2 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 176160 2 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 180256 2 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 237616 4 32
# write offset: 0 104768 0
# cmd_write_packed
# dispatch_write_packed: 108 112 246208 108 104768
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7099
# cmd_write_packed
# dispatch_write_packed: 272 272 266272 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 282656 1 32
# write offset: 0 104880 0
# cmd_write_packed
# dispatch_write_packed: 48 48 291216 96 104880
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7207
# cmd_write_packed
# dispatch_write_packed: 272 272 303136 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 319520 1 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 7303
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7303
# cmd_write_packed
# dispatch_write_packed: 16 16 335904 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7303
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# Function 'ttnn.matmul' executed in 0.0001 seconds
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 128 dispatch_cb_page_size: 4096
# write offset: 0 104928 0
# cmd_write_packed
# dispatch_write_packed: 52 64 360480 1 104928
# cmd_write_packed
# dispatch_write_packed: 68 80 364992 105 104928
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7303
# cmd_write_packed
# dispatch_write_packed: 272 272 380960 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 413744 3 32
# write offset: 0 105008 0
# cmd_write_packed
# dispatch_write_packed: 48 48 421920 1 105008
# cmd_write_packed
# dispatch_write_packed: 64 64 426432 105 105008
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7409
# cmd_write_packed
# dispatch_write_packed: 272 272 438304 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 471088 3 32
# write offset: 0 105072 0
# cmd_write_packed
# dispatch_write_packed: 80 80 479264 1 105072
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7515
# cmd_write_packed
# dispatch_write_packed: 272 272 487456 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 503840 1 32
# write offset: 0 105152 0
# cmd_write_packed
# dispatch_write_packed: 68 80 512448 108 105152
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7516
# cmd_write_packed
# dispatch_write_packed: 16 16 528416 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 540704 1 32
# write offset: 0 105232 0
# cmd_write_packed
# dispatch_write_packed: 48 48 549312 108 105232
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7624
# cmd_write_packed
# dispatch_write_packed: 272 272 561184 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 577568 1 32
# write offset: 0 105280 0
# cmd_write_packed
# dispatch_write_packed: 36 48 586176 108 105280
# cmd_write_packed
# dispatch_write_packed: 36 0 593952 1 105328
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7732
# cmd_write_packed
# dispatch_write_packed: 16 16 602144 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 614432 1 32
# write offset: 0 105376 0
# cmd_write_packed
# dispatch_write_packed: 72 80 622736 31 105376
# cmd_write_packed
# dispatch_write_packed: 92 96 626720 1 105376
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7840
# cmd_write_packed
# dispatch_write_packed: 4 16 110624 2 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 114720 2 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 118816 2 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 176176 4 32
# write offset: 0 105472 0
# cmd_write_packed
# dispatch_write_packed: 108 112 184768 108 105472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7872
# cmd_write_packed
# dispatch_write_packed: 272 272 204832 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 221216 1 32
# write offset: 0 105584 0
# cmd_write_packed
# dispatch_write_packed: 48 48 229776 96 105584
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 7980
# cmd_write_packed
# dispatch_write_packed: 272 272 241696 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 258080 1 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 8076
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8076
# cmd_write_packed
# dispatch_write_packed: 16 16 274464 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# cmd_wait
#  DISPATCH WAIT 1a3b0Function 'ttnn.matmul' executed in 0.0001 seconds
# Function 'ttnn.matmul' executed in 0.0001 seconds
#  count 8076
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1023 page_size: 128 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 128 dispatch_cb_page_size: 4096
# write offset: 0 105632 0
# cmd_write_packed
# dispatch_write_packed: 52 64 299040 1 105632
# cmd_write_packed
# dispatch_write_packed: 68 80 303552 105 105632
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8076
# cmd_write_packed
# dispatch_write_packed: 272 272 319520 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 352304 3 32
# write offset: 0 105712 0
# cmd_write_packed
# dispatch_write_packed: 48 48 360480 1 105712
# cmd_write_packed
# dispatch_write_packed: 64 64 364992 105 105712
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8182
# cmd_write_packed
# dispatch_write_packed: 272 272 376864 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 409648 3 32
# write offset: 0 105776 0
# cmd_write_packed
# dispatch_write_packed: 80 80 417824 1 105776
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8288
# cmd_write_packed
# dispatch_write_packed: 272 272 426016 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 442400 1 32
# write offset: 0 105856 0
# cmd_write_packed
# dispatch_write_packed: 68 80 451008 108 105856
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8289
# cmd_write_packed
# dispatch_write_packed: 16 16 466976 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 479264 1 32
# write offset: 0 105936 0
# cmd_write_packed
# dispatch_write_packed: 36 48 487872 108 105936
# cmd_write_packed
# dispatch_write_packed: 36 0 495648 1 105984
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8397
# cmd_write_packed
# dispatch_write_packed: 16 16 503840 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 516128 1 32
# write offset: 0 106032 0
# cmd_write_packed
# dispatch_write_packed: 60 64 524448 36 106032
# cmd_write_packed
# dispatch_write_packed: 60 64 528688 72 106032
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8505
# cmd_write_packed
# dispatch_write_packed: 272 272 540704 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 565280 2 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8613
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 1 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 106096 0
# cmd_write_packed
# dispatch_write_packed: 52 64 582080 108 106096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8613
# cmd_write_packed
# dispatch_write_packed: 272 272 593952 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 610336 1 32
# write offset: 0 106160 0
# cmd_write_packed
# dispatch_write_packed: 108 112 618944 108 106160
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8721
# cmd_write_packed
# dispatch_write_packed: 272 272 114720 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 131104 1 32
# write offset: 0 106272 0
# cmd_write_packed
# dispatch_write_packed: 96 96 139712 108 106272
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8829
# cmd_write_packed
# dispatch_write_packed: 416 416 155680 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 180256 1 32
# write offset: 0 106368 0
# cmd_write_packed
# dispatch_write_packed: 60 64 188672 60 106368
# cmd_write_packed
# dispatch_write_packed: 60 64 192720 48 106368
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 8937
# cmd_write_packed
# dispatch_write_packed: 272 272 200736 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 241712 4 32
# write offset: 0 106432 0
# cmd_write_packed
# dispatch_write_packed: 52 64 249888 1 106432
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9045
# cmd_write_packed
# dispatch_write_packed: 32 32 258080 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 270368 1 32
# write offset: 0 106496 0
# cmd_write_packed
# dispatch_write_packed: 68 80 278976 108 106496
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9046
# cmd_write_packed
# dispatch_write_packed: 16 16 294944 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 307232 1 32
# write offset: 0 102240 0
# cmd_write_packed
# dispatch_write_packed: 76 80 315424 1 102240
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9154
# cmd_write_packed
# dispatch_write_packed: 272 272 323616 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 340000 1 32
# write offset: 0 102320 0
# cmd_write_packed
# dispatch_write_packed: 52 64 348192 1 102320
# cmd_write_packed
# dispatch_write_packed: 68 80 352704 105 102320
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9155
# cmd_write_packed
# dispatch_write_packed: 272 272 368672 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 401456 3 32
# write offset: 0 102400 0
# cmd_write_packed
# dispatch_write_packed: 48 48 409632 1 102400
# cmd_write_packed
# dispatch_write_packed: 64 64 414144 105 102400
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9261
# cmd_write_packed
# dispatch_write_packed: 272 272 426016 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 458800 3 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 9367
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9367
# cmd_write_packed
# dispatch_write_packed: 16 16 475168 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# Function 'ttnn.matmul' executed in 0.0001 seconds
# Function 'multi_head_attention' executed in 35.0347 seconds
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9367
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096

# %%
print(f"Multi-head attention ran in {duration} seconds for the subsequent iteration because of the program cache")
# Out:
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# Multi-head attention ran in 35.035075664520264 seconds for the subsequent iteration because of the program cache
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102464 0
# cmd_write_packed
# dispatch_write_packed: 48 48 594320 96 102464
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9367
# cmd_write_packed
# dispatch_write_packed: 272 272 606240 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 622624 1 32
# write offset: 0 102512 0
# cmd_write_packed
# dispatch_write_packed: 72 80 630928 31 102512
# cmd_write_packed
# dispatch_write_packed: 92 96 110624 1 102512
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9463
# cmd_write_packed
# dispatch_write_packed: 4 16 118816 2 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 122912 2 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 127008 2 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 184368 4 32
# write offset: 0 102608 0
# cmd_write_packed
# dispatch_write_packed: 108 112 192960 108 102608
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9495
# cmd_write_packed
# dispatch_write_packed: 272 272 213024 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 229408 1 32

# %% [markdown]
# ## Write optimized version of Multi-Head Attention
#
# Optimized version of the multi-head attention can be written by:
#
# - Tilizing all of the tensors ahead of time
# - Using more performant matmuls that fuse bias and specify the number of cores they execute on
# - Putting every tensor into L1
# - Using bfloat8_b data_type
# - Using custom `ttnn.transformer` operations instead of `ttnn.permute` and `ttnn.reshape`
#
# `ttnn.deallocate` calls are needed because otherwise, the cores on the device will run out of the L1 memory

# %%
def optimized_multi_head_attention(
    hidden_states,
    attention_mask,
    fused_qkv_weight,
    fused_qkv_bias,
    self_output_weight,
    self_output_bias,
    *,
    num_heads,
    num_cores_x=12,
):
    batch_size, _, hidden_size = hidden_states.shape
    head_size = hidden_size // num_heads
    
    hidden_states = ttnn.to_layout(hidden_states, ttnn.TILE_LAYOUT)

    fused_qkv_output = ttnn.linear(
        hidden_states,
        fused_qkv_weight,
        bias=fused_qkv_bias,
        memory_config=ttnn.L1_MEMORY_CONFIG,
        dtype=ttnn.bfloat8_b,
        core_grid=ttnn.CoreGrid(y=batch_size, x=num_cores_x),
    )

    (
        query,
        key,
        value,
    ) = ttnn.transformer.split_query_key_value_and_split_heads(
        fused_qkv_output,
        memory_config=ttnn.L1_MEMORY_CONFIG,
        num_heads=num_heads,
    )
    ttnn.deallocate(fused_qkv_output)

    attention_scores = ttnn.matmul(
        query,
        key,
        memory_config=ttnn.L1_MEMORY_CONFIG,
        dtype=ttnn.bfloat16,
        core_grid=ttnn.CoreGrid(y=batch_size, x=num_cores_x),
    )
    ttnn.deallocate(query)
    ttnn.deallocate(key)

    attention_probs = ttnn.transformer.attention_softmax_(attention_scores, attention_mask=attention_mask, head_size=head_size)

    context_layer = ttnn.matmul(
        attention_probs,
        value,
        memory_config=ttnn.L1_MEMORY_CONFIG,
        dtype=ttnn.bfloat8_b,
        core_grid=ttnn.CoreGrid(y=batch_size, x=num_cores_x),
    )
    ttnn.deallocate(attention_probs)

    context_layer_after_concatenate_heads = ttnn.transformer.concatenate_heads(
        context_layer,
        memory_config=ttnn.L1_MEMORY_CONFIG,
    )
    ttnn.deallocate(context_layer)

    self_output = ttnn.linear(
        context_layer_after_concatenate_heads,
        self_output_weight,
        bias=self_output_bias,
        memory_config=ttnn.L1_MEMORY_CONFIG,
        dtype=ttnn.bfloat16,
        core_grid=ttnn.CoreGrid(y=batch_size, x=num_cores_x),
    )
    ttnn.deallocate(context_layer_after_concatenate_heads)

    return self_output

# %% [markdown]
# ## Pre-process the parameters of the optimized model
#
# 1. Fuse QKV weights and biases
# 2. Reshape and tilize for the optimized operations using preprocess_linear_weight and preprocess_linear_bias
# 3. Move to device

# %%
from ttnn.model_preprocessing import (
    preprocess_linear_bias,
    preprocess_linear_weight,
)

torch_qkv_weight = torch.cat([torch_query_weight, torch_key_weight, torch_value_weight], dim=-1)
torch_qkv_bias = torch.cat([torch_query_bias, torch_key_bias, torch_value_bias], dim=-1)

qkv_weight = preprocess_linear_weight(torch_qkv_weight.T, dtype=ttnn.bfloat16)
qkv_bias = preprocess_linear_bias(torch_qkv_bias, dtype=ttnn.bfloat16)
output_weight = preprocess_linear_weight(torch_output_weight.T, dtype=ttnn.bfloat16)
output_bias = preprocess_linear_bias(torch_output_bias, dtype=ttnn.bfloat16)

qkv_weight = ttnn.to_device(qkv_weight, device)
qkv_bias = ttnn.to_device(qkv_bias, device, memory_config=ttnn.L1_MEMORY_CONFIG)
output_weight = ttnn.to_device(output_weight, device)
output_bias = ttnn.to_device(output_bias, device, memory_config=ttnn.L1_MEMORY_CONFIG)
# Out:
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9603
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 48 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9603
# cmd_write_paged is_dram: 0
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 0
# process_write_paged - pages: 33 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9603
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 63 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 16 page_size: 2048 dispatch_cb_page_size: 4096
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9603
# cmd_write_paged is_dram: 0
# process_write_paged - pages: 32 page_size: 2048 dispatch_cb_page_size: 4096

# %% [markdown]
# ## Run the first iteration of the optimized Multi-Head Attention

# %%
start = time.time()
hidden_states = ttnn.to_layout(hidden_states, ttnn.TILE_LAYOUT)
optimized_output = optimized_multi_head_attention(
    hidden_states,
    attention_mask,
    qkv_weight,
    qkv_bias,
    output_weight,
    output_bias,
    num_heads=num_heads,
)
end = time.time()
duration = end - start
# Out:
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9603
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 21 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102720 0
# cmd_write_packed
# dispatch_write_packed: 52 64 188608 42 102720
# cmd_write_packed
# dispatch_write_packed: 72 80 192560 7 102720
# cmd_write_packed
# dispatch_write_packed: 52 64 196768 35 102720
# cmd_write_packed
# dispatch_write_packed: 80 80 200768 11 102720
# cmd_write_packed
# dispatch_write_packed: 100 112 204832 1 102720
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 9603
# cmd_write_packed
# dispatch_write_packed: 4 16 213024 1 107280
# cmd_write_packed
# dispatch_write_packed: 4 16 217120 1 107264
# cmd_write_packed
# dispatch_write_packed: 4 16 221216 1 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 225312 1 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 229408 1 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 303168 5 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9699
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 8 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102832 0
# cmd_write_packed
# dispatch_write_packed: 52 64 336272 96 102832
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 9699
# cmd_write_packed
# dispatch_write_packed: 272 272 348192 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 372768 2 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9795
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 18 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 102896 0
# cmd_write_packed
# dispatch_write_packed: 144 144 426256 64 102896
# cmd_write_packed
# dispatch_write_packed: 144 144 438416 32 102896
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 9795
# cmd_write_packed
# dispatch_write_packed: 400 400 450592 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 483360 2 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9891
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 15 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 103040 0
# cmd_write_packed
# dispatch_write_packed: 96 96 528832 108 103040
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 9891
# cmd_write_packed
# dispatch_write_packed: 448 448 544800 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 569376 1 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 9999
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 17 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 103136 0
# cmd_write_packed
# dispatch_write_packed: 144 144 618768 64 103136
# cmd_write_packed
# dispatch_write_packed: 144 144 630928 32 103136
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 9999
# cmd_write_packed
# dispatch_write_packed: 400 400 118816 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 151584 2 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10095
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 4 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 103280 0
# cmd_write_packed
# dispatch_write_packed: 28 32 176528 96 103280
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 10095
# cmd_write_packed
# dispatch_write_packed: 16 16 184352 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 200736 2 32
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10191
# cmd_write_paged is_dram: 1
# process_write_paged - pages: 22 page_size: 2048 dispatch_cb_page_size: 4096
# write offset: 0 103312 0
# cmd_write_packed
# dispatch_write_packed: 52 64 262304 35 103312
# cmd_write_packed
# dispatch_write_packed: 72 80 266288 7 103312
# cmd_write_packed
# dispatch_write_packed: 52 64 270496 35 103312
# cmd_write_packed
# dispatch_write_packed: 80 80 274496 10 103312
# cmd_write_packed
# dispatch_write_packed: 100 112 278560 1 103312
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 10191
# cmd_write_packed
# dispatch_write_packed: 4 16 286752 1 107280
# cmd_write_packed
# dispatch_write_packed: 4 16 290848 1 107264
# cmd_write_packed
# dispatch_write_packed: 4 16 294944 1 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 299040 1 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 303136 1 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 380992 5 32

# %%
print(f"Optimized multi-head attention ran in {duration} seconds for the first iteration")
# Out:
# Optimized multi-head attention ran in 3.070328712463379 seconds for the first iteration

# %% [markdown]
# ## Run a subsequent iteration of the optimized Multi-Head Attention

# %%
start = time.time()
optimized_output = optimized_multi_head_attention(
    hidden_states,
    attention_mask,
    qkv_weight,
    qkv_bias,
    output_weight,
    output_bias,
    num_heads=num_heads,
)
end = time.time()
duration = end - start
# Out:
# write offset: 0 103424 0
# cmd_write_packed
# dispatch_write_packed: 52 64 389312 42 103424
# cmd_write_packed
# dispatch_write_packed: 72 80 393264 7 103424
# cmd_write_packed
# dispatch_write_packed: 52 64 397472 35 103424
# cmd_write_packed
# dispatch_write_packed: 80 80 401472 11 103424
# cmd_write_packed
# dispatch_write_packed: 100 112
# 405536 1 103424
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10279
# cmd_write_packed
# dispatch_write_packed: 4 16 413728 1 107280
# cmd_write_packed
# dispatch_write_packed: 4 16 417824 1 107264
# cmd_write_packed
# dispatch_write_packed: 4 16 421920 1 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 426016 1 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 430112 1 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 503872 5 32
# write offset: 0 103536 0
# cmd_write_packed
# dispatch_write_packed: 52 64 512400 96 103536
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10375
# cmd_write_packed
# dispatch_write_packed: 272 272 524320 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 548896 2 32
# write offset: 0 103600 0
# cmd_write_packed
# dispatch_write_packed: 144 144 557328 64 103600
# cmd_write_packed
# dispatch_write_packed: 144 144 569488 32 103600
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10471
# cmd_write_packed
# dispatch_write_packed: 400 400 581664 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 614432 2 32
# write offset: 0 103744 0
# cmd_write_packed
# dispatch_write_packed: 96 96 623040 108 103744
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10567
# cmd_write_packed
# dispatch_write_packed: 448 448 114720 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 139296 1 32
# write offset: 0 103840 0
# cmd_write_packed
# dispatch_write_packed: 144 144 147728 64 103840
# cmd_write_packed
# dispatch_write_packed: 144 144 159888 32 103840
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10675
# cmd_write_packed
# dispatch_write_packed: 400 400 172064 1 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 204832 2 32
# write offset: 0 103984 0
# cmd_write_packed
# dispatch_write_packed: 28 32 213392 96 103984
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10771
# cmd_write_packed
# dispatch_write_packed: 16 16 221216 2 106592
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 237600 2 32
# write offset: 0 104016 0
# cmd_write_packed
# dispatch_write_packed: 52 64 245920 35 104016
# cmd_write_packed
# dispatch_write_packed: 72 80 249904 7 104016
# cmd_write_packed
# dispatch_write_packed: 52 64 254112 35 104016
# cmd_write_packed
# dispatch_write_packed: 80 80 258112 10 104016
# cmd_write_packed
# dispatch_write_packed: 100 112 262176 1 104016
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10867
# cmd_write_packed
# dispatch_write_packed: 4 16 270368 1 107280
# cmd_write_packed
# dispatch_write_packed: 4 16 274464 1 107264
# cmd_write_packed
# dispatch_write_packed: 4 16 278560 1 107248
# cmd_write_packed
# dispatch_write_packed: 4 16 282656 1 107232
# cmd_write_packed
# dispatch_write_packed: 400 400 286752 1 106592
# cmd_write_packed_large
# cmd_write_packed_large
# cmd_wait
#  DISPATCH BARRIER
# cmd_write_packed
# dispatch_write_packed: 36 48 364608 5 32

# %%
print(f"Optimized multi-head attention ran in {duration} seconds for the subsequent iteration because of the program cache")
# Out:
# Optimized multi-head attention ran in 0.001035928726196289 seconds for the subsequent iteration because of the program cache

# %% [markdown]
# Note that the optimized multi-head attention is 2 orders of magnitude faster than the initial version

# %% [markdown]
# ## Check that the output of the optimized version matches the output of the original implementation

# %%
torch_output = ttnn.to_torch(output)
torch_optimized_output = ttnn.to_torch(optimized_output)

assert torch.allclose(torch_output, torch_optimized_output)
# Out:
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 10955
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10955
# cmd_write_packed
# dispatch_write_packed: 16 16 380960 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# cmd_wait
#  DISPATCH BARRIER
#  DISPATCH WAIT 1a3b0 count 10955
# cmd_write_linear_h_host
# process_write_host_h: 6291472
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10955
# cmd_write_packed
# dispatch_write_packed: 16 16 401440 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32

# %% [markdown]
# ## Close the device

# %%
ttnn.close_device(device)
# Out:
# cmd_wait
#  DISPATCH WAIT 1a3b0 count 10955
#                   Metal | INFO     | Closing device 0
# cmd_write_packed
# dispatch_write_packed: 16 16 413728 1 107408
# cmd_write_linear_h_host
# process_write_host_h: 32
# dispatch terminate
# prefetcher_11: out
# dispatch_11: out
#                   Metal | INFO     | DPRINT Server dettached device 0
#                   Metal | INFO     | Disabling and clearing program cache on device 0
